# %% [markdown]
# Import the required packages with their customary aliases as follows:
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# Using the pandas read_csv() function, read the GDP dataset into your notebook as a DataFrame called gdp_df. Take a look at the first 6 rows. Repeat for the internet use dataset. Call this DataFrame internet_df. Take a look at the first six rows.

# %%
gdp_df = pd.read_csv('C:/Users/wmcwi/Documents/gdp/data/gdp_percapita.csv')

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  1734.723214              NaN
# 1     Afghanistan  2017  1758.465636              NaN
# 2     Afghanistan  2016  1757.023490              NaN
# 3     Afghanistan  2015  1766.593077              NaN
# 4     Afghanistan  2014  1795.735834              NaN
# 5     Afghanistan  2013  1807.762344              NaN

# %%
internet_df = pd.read_csv('C:/Users/wmcwi/Documents/gdp/data/internet_use.csv')

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year        Value Value Footnotes  extra_column1  \
# 0     Afghanistan  2014         6.39             NaN            NaN
# 1     Afghanistan  2013          5.9             NaN            NaN
# 2     Afghanistan  2012  5.454545455             NaN            NaN
# 3     Afghanistan  2011            5             NaN            NaN
# 4     Afghanistan  2010            4             NaN            NaN
# 5     Afghanistan  2009         3.55             NaN            NaN
#
#   extra_column_2
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN

# %% [markdown]
# Look at the shape of each dataframe - how many rows, how many columns.

# %%
gdp_df.shape
# Out:
# (6731, 4)

# %%
internet_df.shape
# Out:
# (4677, 6)

# %% [markdown]
# Take a look at the data types for the columns in each table.

# %%
print(gdp_df.dtypes)
# Out:
# Country or Area     object
# Year                object
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
print(internet_df.dtypes)
# Out:
# Country or Area     object
# Year                object
# Value               object
# Value Footnotes     object
# extra_column1      float64
# extra_column_2      object
# dtype: object

# %% [markdown]
# Take a look at the last 10 rows of each dataset in turn.

# %%
gdp_df.tail(10)
# Out:
#      Country or Area                                      Year        Value  \
# 6721        Zimbabwe                                      1997  3036.422224
# 6722        Zimbabwe                                      1996  2985.856605
# 6723        Zimbabwe                                      1995  2736.486436
# 6724        Zimbabwe                                      1994  2768.309953
# 6725        Zimbabwe                                      1993  2572.870395
# 6726        Zimbabwe                                      1992  2591.007534
# 6727        Zimbabwe                                      1991  2906.272849
# 6728        Zimbabwe                                      1990  2819.549467
# 6729   footnoteSeqID                                  Footnote          NaN
# 6730               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 6721              NaN
# 6722              NaN
# 6723              NaN
# 6724              NaN
# 6725              NaN
# 6726              NaN
# 6727              NaN
# 6728              NaN
# 6729              NaN
# 6730              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area                                               Year  \
# 4667             171                        Internet Dial-up customers.
# 4668             172  Population age 16+ using the Internet in the l...
# 4669             173  Population age 16+ using internet in the last ...
# 4670             174  U.S. Census Bureau, Table 2. Reported Internet...
# 4671             175             Includes individuals 3 years and older
# 4672             176                                   NTIA/CPS survey.
# 4673             177                     Pew Internet Project, Internet
# 4674             178  Estimated based on Survey's results. Populatio...
# 4675             179                     Preliminary. Country estimate.
# 4676             180  The methodology used to estimated the figure f...
#
#                                      Value Value Footnotes  extra_column1  \
# 4667                                   NaN             NaN            NaN
# 4668                                   NaN             NaN            NaN
# 4669                                   NaN             NaN            NaN
# 4670                                   NaN             NaN            NaN
# 4671                                   NaN             NaN            NaN
# 4672                                   NaN             NaN            NaN
# 4673   Broadband and cell phone statistics     ” January 5         2010.0
# 4674                                   NaN             NaN            NaN
# 4675                                   NaN             NaN            NaN
# 4676                                   NaN             NaN            NaN
#
#                                          extra_column_2
# 4667                                                NaN
# 4668                                                NaN
# 4669                                                NaN
# 4670                                                NaN
# 4671                                                NaN
# 4672                                                NaN
# 4673   http://www.pewinternet.org/~/media//Files/Rep...
# 4674                                                NaN
# 4675                                                NaN
# 4676                                                NaN

# %% [markdown]
# Drop the 'value footnotes' data from both datasets. Check that this worked as expected.

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df.pop('Value Footnotes')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#         ..
# 6701   NaN
# 6702   NaN
# 6703   NaN
# 6704   NaN
# 6705   NaN
# 6706   NaN
# 6707   NaN
# 6708   NaN
# 6709   NaN
# 6710   NaN
# 6711   NaN
# 6712   NaN
# 6713   NaN
# 6714   NaN
# 6715   NaN
# 6716   NaN
# 6717   NaN
# 6718   NaN
# 6719   NaN
# 6720   NaN
# 6721   NaN
# 6722   NaN
# 6723   NaN
# 6724   NaN
# 6725   NaN
# 6726   NaN
# 6727   NaN
# 6728   NaN
# 6729   NaN
# 6730   NaN
# Name: Value Footnotes, Length: 6731, dtype: float64

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2018  1734.723214
# 1     Afghanistan  2017  1758.465636
# 2     Afghanistan  2016  1757.023490
# 3     Afghanistan  2015  1766.593077
# 4     Afghanistan  2014  1795.735834

# %%
internet_df = internet_df.drop(['Value Footnotes'], axis=1)

# %%
internet_df.head()
# Out:
#   Country or Area  Year        Value  extra_column1 extra_column_2
# 0     Afghanistan  2014         6.39            NaN            NaN
# 1     Afghanistan  2013          5.9            NaN            NaN
# 2     Afghanistan  2012  5.454545455            NaN            NaN
# 3     Afghanistan  2011            5            NaN            NaN
# 4     Afghanistan  2010            4            NaN            NaN

# %% [markdown]
# Change the columns for the GDP Per Capita data frame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.
#
# Change the columns for the Internet Users data frame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’

# %%
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country', 'Value': 'GDP_Per_Capita'})

# %%
internet_df = internet_df.rename(columns={'Country or Area': 'Country', 'Value': 'Internet_Users_Pct'})

# %%
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2018     1734.723214
# 1  Afghanistan  2017     1758.465636
# 2  Afghanistan  2016     1757.023490
# 3  Afghanistan  2015     1766.593077
# 4  Afghanistan  2014     1795.735834

# %%
internet_df.head()
# Out:
#        Country  Year Internet_Users_Pct  extra_column1 extra_column_2
# 0  Afghanistan  2014               6.39            NaN            NaN
# 1  Afghanistan  2013                5.9            NaN            NaN
# 2  Afghanistan  2012        5.454545455            NaN            NaN
# 3  Afghanistan  2011                  5            NaN            NaN
# 4  Afghanistan  2010                  4            NaN            NaN

# %% [markdown]
# Merge the two DataFrames to one. Merge all rows from each of the two DataFrames.
# Call the new DataFrame gdp_and_internet_use.
#
# Look at the first five rows of your new data frame to confirm the columns are how you expect.
#
# Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df,  how='inner')
gdp_and_internet_use
# Out:
#             Country      Year  GDP_Per_Capita Internet_Users_Pct  \
# 0       Afghanistan      2014     1795.735834               6.39
# 1       Afghanistan      2013     1807.762344                5.9
# 2       Afghanistan      2012     1772.764974        5.454545455
# 3       Afghanistan      2011     1626.764793                  5
# 4       Afghanistan      2010     1671.581238                  4
# 5       Afghanistan      2009     1502.354073               3.55
# 6       Afghanistan      2008     1267.644939               1.84
# 7       Afghanistan      2007     1247.753118                1.9
# 8       Afghanistan      2006     1123.871323        2.107123645
# 9       Afghanistan      2005     1099.104568        1.224148084
# 10      Afghanistan      2004     1025.208245         0.10580903
# 11      Afghanistan      2003     1055.557459        0.087891253
# 12      Afghanistan      2002     1016.245409        0.004561395
# 13          Albania      2014    10700.993216               60.1
# 14          Albania      2013    10492.669028               57.2
# 15          Albania      2012    10369.561032        54.65595904
# 16          Albania      2011    10207.752347                 49
# 17          Albania      2010     9927.638204                 45
# 18          Albania      2009     9525.377979               41.2
# 19          Albania      2008     9154.713749              23.86
# 20          Albania      2007     8450.918236        15.03611541
# 21          Albania      2006     7914.035853        9.609991316
# 22          Albania      2005     7426.115443        6.043890864
# 23          Albania      2004     7001.054082        2.420387798
# 24          Albania      2003     6607.767627        0.971900415
# 25          Albania      2002     6238.119724        0.390081273
# 26          Albania      2001     5949.343236        0.325798377
# 27          Albania      2000     5442.578047        0.114097347
# 28          Albania      1999     5056.566515        0.081437045
# 29          Albania      1998     4450.922523         0.06502737
# ...             ...       ...             ...                ...
# 3490         Zambia      1999     2102.074889        0.147053172
# 3491         Zambia      1998     2064.467651        0.030226183
# 3492         Zambia      1997     2130.519957        0.009329658
# 3493         Zambia      1996     2108.910953        0.009069176
# 3494         Zambia      1995     2038.510332        0.008783623
# 3495         Zambia      1994     2031.776457        0.006776105
# 3496         Zambia      1990     2339.137959                  0
# 3497       Zimbabwe      2014     2506.490220              19.89
# 3498       Zimbabwe      2013     2491.635140               18.5
# 3499       Zimbabwe      2012     2486.847930              17.09
# 3500       Zimbabwe      2011     2168.110293               15.7
# 3501       Zimbabwe      2010     1928.017081               11.5
# 3502       Zimbabwe      2009     1632.999866              11.36
# 3503       Zimbabwe      2008     1475.140653               11.4
# 3504       Zimbabwe      2007     1809.791702              10.85
# 3505       Zimbabwe      2006     1893.936230        9.791841502
# 3506       Zimbabwe      2005     1974.645081        8.015978089
# 3507       Zimbabwe      2004     2104.143512        6.564045027
# 3508       Zimbabwe      2003     2240.903026        6.394786458
# 3509       Zimbabwe      2002     2706.031494        3.994356135
# 3510       Zimbabwe      2001     2977.768505        0.799846046
# 3511       Zimbabwe      2000     2945.993212        0.401433535
# 3512       Zimbabwe      1999     3054.064189        0.161675528
# 3513       Zimbabwe      1998     3099.076182        0.081648476
# 3514       Zimbabwe      1997     3036.422224        0.033080327
# 3515       Zimbabwe      1996     2985.856605        0.016790484
# 3516       Zimbabwe      1995     2736.486436         0.00768354
# 3517       Zimbabwe      1994     2768.309953         0.00173928
# 3518       Zimbabwe      1990     2819.549467                  0
# 3519  footnoteSeqID  Footnote             NaN                NaN
#
#       extra_column1 extra_column_2
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# 5               NaN            NaN
# 6               NaN            NaN
# 7               NaN            NaN
# 8               NaN            NaN
# 9               NaN            NaN
# 10              NaN            NaN
# 11              NaN            NaN
# 12              NaN            NaN
# 13              NaN            NaN
# 14              NaN            NaN
# 15              NaN            NaN
# 16              NaN            NaN
# 17              NaN            NaN
# 18              NaN            NaN
# 19              NaN            NaN
# 20              NaN            NaN
# 21              NaN            NaN
# 22              NaN            NaN
# 23              NaN            NaN
# 24              NaN            NaN
# 25              NaN            NaN
# 26              NaN            NaN
# 27              NaN            NaN
# 28              NaN            NaN
# 29              NaN            NaN
# ...             ...            ...
# 3490            NaN            NaN
# 3491            NaN            NaN
# 3492            NaN            NaN
# 3493            NaN            NaN
# 3494            NaN            NaN
# 3495            NaN            NaN
# 3496            NaN            NaN
# 3497            NaN            NaN
# 3498            NaN            NaN
# 3499            NaN            NaN
# 3500            NaN            NaN
# 3501            NaN            NaN
# 3502            NaN            NaN
# 3503            NaN            NaN
# 3504            NaN            NaN
# 3505            NaN            NaN
# 3506            NaN            NaN
# 3507            NaN            NaN
# 3508            NaN            NaN
# 3509            NaN            NaN
# 3510            NaN            NaN
# 3511            NaN            NaN
# 3512            NaN            NaN
# 3513            NaN            NaN
# 3514            NaN            NaN
# 3515            NaN            NaN
# 3516            NaN            NaN
# 3517            NaN            NaN
# 3518            NaN            NaN
# 3519            NaN            NaN
#
# [3520 rows x 6 columns]

# %%
gdp_and_internet_use
# Out:
#             Country      Year  GDP_Per_Capita Internet_Users_Pct  \
# 0       Afghanistan      2014     1795.735834               6.39
# 1       Afghanistan      2013     1807.762344                5.9
# 2       Afghanistan      2012     1772.764974        5.454545455
# 3       Afghanistan      2011     1626.764793                  5
# 4       Afghanistan      2010     1671.581238                  4
# 5       Afghanistan      2009     1502.354073               3.55
# 6       Afghanistan      2008     1267.644939               1.84
# 7       Afghanistan      2007     1247.753118                1.9
# 8       Afghanistan      2006     1123.871323        2.107123645
# 9       Afghanistan      2005     1099.104568        1.224148084
# 10      Afghanistan      2004     1025.208245         0.10580903
# 11      Afghanistan      2003     1055.557459        0.087891253
# 12      Afghanistan      2002     1016.245409        0.004561395
# 13          Albania      2014    10700.993216               60.1
# 14          Albania      2013    10492.669028               57.2
# 15          Albania      2012    10369.561032        54.65595904
# 16          Albania      2011    10207.752347                 49
# 17          Albania      2010     9927.638204                 45
# 18          Albania      2009     9525.377979               41.2
# 19          Albania      2008     9154.713749              23.86
# 20          Albania      2007     8450.918236        15.03611541
# 21          Albania      2006     7914.035853        9.609991316
# 22          Albania      2005     7426.115443        6.043890864
# 23          Albania      2004     7001.054082        2.420387798
# 24          Albania      2003     6607.767627        0.971900415
# 25          Albania      2002     6238.119724        0.390081273
# 26          Albania      2001     5949.343236        0.325798377
# 27          Albania      2000     5442.578047        0.114097347
# 28          Albania      1999     5056.566515        0.081437045
# 29          Albania      1998     4450.922523         0.06502737
# ...             ...       ...             ...                ...
# 3490         Zambia      1999     2102.074889        0.147053172
# 3491         Zambia      1998     2064.467651        0.030226183
# 3492         Zambia      1997     2130.519957        0.009329658
# 3493         Zambia      1996     2108.910953        0.009069176
# 3494         Zambia      1995     2038.510332        0.008783623
# 3495         Zambia      1994     2031.776457        0.006776105
# 3496         Zambia      1990     2339.137959                  0
# 3497       Zimbabwe      2014     2506.490220              19.89
# 3498       Zimbabwe      2013     2491.635140               18.5
# 3499       Zimbabwe      2012     2486.847930              17.09
# 3500       Zimbabwe      2011     2168.110293               15.7
# 3501       Zimbabwe      2010     1928.017081               11.5
# 3502       Zimbabwe      2009     1632.999866              11.36
# 3503       Zimbabwe      2008     1475.140653               11.4
# 3504       Zimbabwe      2007     1809.791702              10.85
# 3505       Zimbabwe      2006     1893.936230        9.791841502
# 3506       Zimbabwe      2005     1974.645081        8.015978089
# 3507       Zimbabwe      2004     2104.143512        6.564045027
# 3508       Zimbabwe      2003     2240.903026        6.394786458
# 3509       Zimbabwe      2002     2706.031494        3.994356135
# 3510       Zimbabwe      2001     2977.768505        0.799846046
# 3511       Zimbabwe      2000     2945.993212        0.401433535
# 3512       Zimbabwe      1999     3054.064189        0.161675528
# 3513       Zimbabwe      1998     3099.076182        0.081648476
# 3514       Zimbabwe      1997     3036.422224        0.033080327
# 3515       Zimbabwe      1996     2985.856605        0.016790484
# 3516       Zimbabwe      1995     2736.486436         0.00768354
# 3517       Zimbabwe      1994     2768.309953         0.00173928
# 3518       Zimbabwe      1990     2819.549467                  0
# 3519  footnoteSeqID  Footnote             NaN                NaN
#
#       extra_column1 extra_column_2
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# 5               NaN            NaN
# 6               NaN            NaN
# 7               NaN            NaN
# 8               NaN            NaN
# 9               NaN            NaN
# 10              NaN            NaN
# 11              NaN            NaN
# 12              NaN            NaN
# 13              NaN            NaN
# 14              NaN            NaN
# 15              NaN            NaN
# 16              NaN            NaN
# 17              NaN            NaN
# 18              NaN            NaN
# 19              NaN            NaN
# 20              NaN            NaN
# 21              NaN            NaN
# 22              NaN            NaN
# 23              NaN            NaN
# 24              NaN            NaN
# 25              NaN            NaN
# 26              NaN            NaN
# 27              NaN            NaN
# 28              NaN            NaN
# 29              NaN            NaN
# ...             ...            ...
# 3490            NaN            NaN
# 3491            NaN            NaN
# 3492            NaN            NaN
# 3493            NaN            NaN
# 3494            NaN            NaN
# 3495            NaN            NaN
# 3496            NaN            NaN
# 3497            NaN            NaN
# 3498            NaN            NaN
# 3499            NaN            NaN
# 3500            NaN            NaN
# 3501            NaN            NaN
# 3502            NaN            NaN
# 3503            NaN            NaN
# 3504            NaN            NaN
# 3505            NaN            NaN
# 3506            NaN            NaN
# 3507            NaN            NaN
# 3508            NaN            NaN
# 3509            NaN            NaN
# 3510            NaN            NaN
# 3511            NaN            NaN
# 3512            NaN            NaN
# 3513            NaN            NaN
# 3514            NaN            NaN
# 3515            NaN            NaN
# 3516            NaN            NaN
# 3517            NaN            NaN
# 3518            NaN            NaN
# 3519            NaN            NaN
#
# [3520 rows x 6 columns]

# %%
gdp_and_internet_use = gdp_and_internet_use.drop(['extra_column1'], axis=1)

# %%
gdp_and_internet_use = gdp_and_internet_use.drop(['extra_column_2'], axis=1)

# %%
gdp_and_internet_use.tail()
# Out:
#             Country      Year  GDP_Per_Capita Internet_Users_Pct
# 3515       Zimbabwe      1996     2985.856605        0.016790484
# 3516       Zimbabwe      1995     2736.486436         0.00768354
# 3517       Zimbabwe      1994     2768.309953         0.00173928
# 3518       Zimbabwe      1990     2819.549467                  0
# 3519  footnoteSeqID  Footnote             NaN                NaN

# %% [markdown]
#
#
# Look at the shape of the new dataset. Were any rows dropped?
#
# Yes. Approximatly 3000.

# %%
gdp_and_internet_use.shape
# Out:
# (3520, 4)

# %% [markdown]
# Subset the combined data frame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
years_list = ['2004', '2009', '2014']

# %%
gdp_and_internet_use[gdp_and_internet_use.Year.isin(years_list)]
# Out:
#                    Country  Year  GDP_Per_Capita Internet_Users_Pct
# 0              Afghanistan  2014     1795.735834               6.39
# 5              Afghanistan  2009     1502.354073               3.55
# 10             Afghanistan  2004     1025.208245         0.10580903
# 13                 Albania  2014    10700.993216               60.1
# 18                 Albania  2009     9525.377979               41.2
# 23                 Albania  2004     7001.054082        2.420387798
# 34                 Algeria  2014    13557.769757              18.09
# 39                 Algeria  2009    12697.690780              11.23
# 44                 Algeria  2004    11845.170512        4.634475088
# 56                  Angola  2014     6813.052106              21.26
# 61                  Angola  2009     6292.534856                  6
# 66                  Angola  2004     4604.657044        0.464814618
# 76     Antigua and Barbuda  2014    20440.540555                 64
# 81     Antigua and Barbuda  2009    22568.626530                 42
# 86     Antigua and Barbuda  2004    21161.123532        24.26654372
# 97               Argentina  2014    18935.002497               64.7
# 102              Argentina  2009    17302.654149                 34
# 107              Argentina  2004    14498.772332        16.03668411
# 121                Armenia  2014     7954.195331               46.3
# 126                Armenia  2009     6534.077152               15.3
# 131                Armenia  2004     4673.816503        4.899008571
# 143                  Aruba  2014    36172.933355              83.78
# 148                  Aruba  2009    35830.497958                 58
# 153                  Aruba  2004    39553.374074                 23
# 161              Australia  2014    43651.103133              84.56
# 166              Australia  2009    41326.391930              74.25
# 183                Austria  2014    44246.893271                 81
# 188                Austria  2009    42656.854690              73.45
# 193                Austria  2004    40652.811067              54.28
# 208             Azerbaijan  2014    16853.568469                 61
# ...                    ...   ...             ...                ...
# 3297  United Arab Emirates  2014    62879.703021               90.4
# 3302  United Arab Emirates  2009    58843.469424                 64
# 3307  United Arab Emirates  2004    98543.247451        30.13129617
# 3318        United Kingdom  2014    38693.893263              91.61
# 3323        United Kingdom  2009    36464.420182              83.56
# 3328        United Kingdom  2004    36495.104697              65.61
# 3343         United States  2014    52080.792568              87.36
# 3348         United States  2009    48644.151110                 71
# 3353         United States  2004    48275.386104        64.75825648
# 3368               Uruguay  2014    19939.005008              61.46
# 3373               Uruguay  2009    15962.914949               41.8
# 3378               Uruguay  2004    12089.985392        17.06309834
# 3390            Uzbekistan  2014     6498.139042              43.55
# 3395            Uzbekistan  2009     5012.818582        17.05821621
# 3400            Uzbekistan  2004     3631.152016        2.593725421
# 3411               Vanuatu  2014     2837.122659               18.8
# 3416               Vanuatu  2009     2976.972907                7.5
# 3421               Vanuatu  2004     2541.779079        4.746602619
# 3431             Venezuela  2014    17131.386907                 57
# 3436             Venezuela  2009    17392.390080               32.7
# 3441             Venezuela  2004    13960.541976        8.404469592
# 3455                 Yemen  2014     3828.484887              22.55
# 3460                 Yemen  2009     4359.812628               9.96
# 3465                 Yemen  2004     4145.345441        0.881222989
# 3475                Zambia  2014     3684.685507              17.34
# 3480                Zambia  2009     3115.937579               6.31
# 3485                Zambia  2004     2415.590117        2.013549532
# 3497              Zimbabwe  2014     2506.490220              19.89
# 3502              Zimbabwe  2009     1632.999866              11.36
# 3507              Zimbabwe  2004     2104.143512        6.564045027
#
# [488 rows x 4 columns]

# %% [markdown]
# Create three new data frames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
the_2004 = gdp_and_internet_use[gdp_and_internet_use['Year'] == '2004']

# %%
the_2009 = gdp_and_internet_use[gdp_and_internet_use['Year'] == '2009']

# %%
the_2014 = gdp_and_internet_use[gdp_and_internet_use['Year'] == '2014']

# %% [markdown]
# Which country had the highest percentage of internet users in 2014? What was the percentage? Repeat for 2004 and 2009.
# (Try typing the first 3 letters of your DataFrame name and hitting the tab for auto-complete options).
#
#
#         3002	Sweden	 2004		83.89
#         1400	Iceland	 2009		93
#         1395	Iceland	 2014		98.16

# %%
the_2004['Internet_Users_Pct'] = pd.to_numeric(the_2004['Internet_Users_Pct'])
# Out:
# C:\Users\wmcwi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
the_2004_max = the_2004['Internet_Users_Pct'].max()
the_2004_max
# Out:
# 83.89

# %%
the_2009_max = the_2009['Internet_Users_Pct'].max()
the_2009_max
# Out:
# '93'

# %%
the_2014_max = the_2014['Internet_Users_Pct'].max()
the_2014_max
# Out:
# '98.16'

# %%
the_2004.sort_values(by='Internet_Users_Pct').tail(3)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 864   Denmark  2004    43670.446201               80.93
# 1405  Iceland  2004    38893.378798               83.88
# 3002   Sweden  2004    40177.850408               83.89

# %% [markdown]
# Which country had the lowest percentage of internet users in 2014? What was the percentage? Repeat for 2004 and 2009.
#
#
#                 2146	Myanmar	     2004	   0.024337
#                 3109    Timor-Leste	 2009	   0.18525151
#                 1275    Timor-Leste	 2014	   1.14

# %%
the_2004_min = the_2004['Internet_Users_Pct'].min()
the_2004_min
# Out:
# 0.024337392000000003

# %%
the_2009_min = the_2009['Internet_Users_Pct'].min()
the_2009_min
# Out:
# '0.18525151'

# %%
the_2014_min = the_2014['Internet_Users_Pct'].min()
the_2014_min
# Out:
# '1.14'

# %%
the_2014.sort_values(by='Internet_Users_Pct').head(3)
# Out:
#           Country  Year  GDP_Per_Capita Internet_Users_Pct
# 3104  Timor-Leste  2014     6466.737732               1.14
# 539       Burundi  2014      768.469837               1.38
# 1275       Guinea  2014     1836.532318               1.72

# %% [markdown]
# Which country had the highest gdp per capita in 2014? What was the gdp per capita?
#
#                     2556	Qatar	 2014	116693.507701
#
# Which country had the lowest gdp per capita in 2014? What was the gdp per capita?
#
#                     539	    Burundi	 2014	768.469837

# %%
gdp_per_cap_2014_max = the_2014['GDP_Per_Capita'].max()
gdp_per_cap_2014_max
# Out:
# 116693.50770116401

# %%
gdp_per_cap_2014_min = the_2014['GDP_Per_Capita'].min()
gdp_per_cap_2014_min
# Out:
# 768.469836927654

# %%
the_2014.sort_values(by='GDP_Per_Capita').tail(5)
# Out:
#          Country  Year  GDP_Per_Capita Internet_Users_Pct
# 2310      Norway  2014    63328.259526               96.3
# 1685      Kuwait  2014    72588.670676               78.7
# 2765   Singapore  2014    81965.361071                 82
# 1812  Luxembourg  2014    92349.186429              94.67
# 2556       Qatar  2014   116693.507701              91.49

# %% [markdown]
# Create some scatterplots:
#
#     a. 2004 Percent Using the Internet vs GDP Per Capita
#
#     b. 2009 Percent Using the Internet vs GDP Per Capita
#
#     c. 2014 Percent Using the Internet vs GDP Per Capita
#
# Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.
#
# convert all data to floats

# %%
plt.scatter(the_2004['Internet_Users_Pct'], the_2004['GDP_Per_Capita'] )

# %%
plt.scatter(the_2009['Internet_Users_Pct'], the_2009['GDP_Per_Capita'] )

# %%
plt.scatter(the_2014['Internet_Users_Pct'], the_2014['GDP_Per_Capita'] )
