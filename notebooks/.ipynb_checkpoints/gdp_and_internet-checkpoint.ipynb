# %% [markdown]
# Import the required packages with their customary aliases as follows:
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# Using the pandas read_csv() function, read the GDP dataset into your notebook as a DataFrame called gdp_df. Take a look at the first 6 rows. Repeat for the internet use dataset. Call this DataFrame internet_df. Take a look at the first six rows.

# %%
gdp_df = pd.read_csv('C:/Users/wmcwi/Documents/gdp/data/gdp_percapita.csv', nrows= 6729)

# %%
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6724        Zimbabwe  1994  2768.309953              NaN
# 6725        Zimbabwe  1993  2572.870395              NaN
# 6726        Zimbabwe  1992  2591.007534              NaN
# 6727        Zimbabwe  1991  2906.272849              NaN
# 6728        Zimbabwe  1990  2819.549467              NaN

# %%
internet_df = pd.read_csv('C:/Users/wmcwi/Documents/gdp/data/internet_use.csv', nrows=4495)

# %%
internet_df.tail()
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# Look at the shape of each dataframe - how many rows, how many columns.

# %%
gdp_df.shape
# Out:
# (6729, 4)

# %%
internet_df.shape
# Out:
# (4495, 4)

# %% [markdown]
# Take a look at the data types for the columns in each table.

# %%
print(gdp_df.dtypes)
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
print(internet_df.dtypes)
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# Take a look at the last 10 rows of each dataset in turn.

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6719        Zimbabwe  1999  3054.064189              NaN
# 6720        Zimbabwe  1998  3099.076182              NaN
# 6721        Zimbabwe  1997  3036.422224              NaN
# 6722        Zimbabwe  1996  2985.856605              NaN
# 6723        Zimbabwe  1995  2736.486436              NaN
# 6724        Zimbabwe  1994  2768.309953              NaN
# 6725        Zimbabwe  1993  2572.870395              NaN
# 6726        Zimbabwe  1992  2591.007534              NaN
# 6727        Zimbabwe  1991  2906.272849              NaN
# 6728        Zimbabwe  1990  2819.549467              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# Drop the 'value footnotes' data from both datasets. Check that this worked as expected.

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df.pop('Value Footnotes')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#         ..
# 6699   NaN
# 6700   NaN
# 6701   NaN
# 6702   NaN
# 6703   NaN
# 6704   NaN
# 6705   NaN
# 6706   NaN
# 6707   NaN
# 6708   NaN
# 6709   NaN
# 6710   NaN
# 6711   NaN
# 6712   NaN
# 6713   NaN
# 6714   NaN
# 6715   NaN
# 6716   NaN
# 6717   NaN
# 6718   NaN
# 6719   NaN
# 6720   NaN
# 6721   NaN
# 6722   NaN
# 6723   NaN
# 6724   NaN
# 6725   NaN
# 6726   NaN
# 6727   NaN
# 6728   NaN
# Name: Value Footnotes, Length: 6729, dtype: float64

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2018  1734.723214
# 1     Afghanistan  2017  1758.465636
# 2     Afghanistan  2016  1757.023490
# 3     Afghanistan  2015  1766.593077
# 4     Afghanistan  2014  1795.735834

# %%
internet_df = internet_df.drop(['Value Footnotes'], axis=1)

# %%
internet_df.head()
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000

# %% [markdown]
# Change the columns for the GDP Per Capita data frame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.
#
# Change the columns for the Internet Users data frame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’

# %%
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country', 'Value': 'GDP_Per_Capita'})

# %%
internet_df = internet_df.rename(columns={'Country or Area': 'Country', 'Value': 'Internet_Users_Pct'})

# %%
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2018     1734.723214
# 1  Afghanistan  2017     1758.465636
# 2  Afghanistan  2016     1757.023490
# 3  Afghanistan  2015     1766.593077
# 4  Afghanistan  2014     1795.735834

# %%
internet_df.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
internet_df['Internet_Users_Pct'].dtype
# Out:
# dtype('float64')

# %%
gdp_df['GDP_Per_Capita'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Merge the two DataFrames to one. Merge all rows from each of the two DataFrames.
# Call the new DataFrame gdp_and_internet_use.
#
# Look at the first five rows of your new data frame to confirm the columns are how you expect.
#
# Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df,  how='outer')
gdp_and_internet_use
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0               Afghanistan  2018     1734.723214                 NaN
# 1               Afghanistan  2017     1758.465636                 NaN
# 2               Afghanistan  2016     1757.023490                 NaN
# 3               Afghanistan  2015     1766.593077                 NaN
# 4               Afghanistan  2014     1795.735834            6.390000
# 5               Afghanistan  2013     1807.762344            5.900000
# 6               Afghanistan  2012     1772.764974            5.454545
# 7               Afghanistan  2011     1626.764793            5.000000
# 8               Afghanistan  2010     1671.581238            4.000000
# 9               Afghanistan  2009     1502.354073            3.550000
# 10              Afghanistan  2008     1267.644939            1.840000
# 11              Afghanistan  2007     1247.753118            1.900000
# ...

# %% [markdown]
#
#
# Look at the shape of the new dataset. Were any rows dropped?
#
# yes

# %%
gdp_and_internet_use.shape
# Out:
# (7705, 4)

# %% [markdown]
# Subset the combined data frame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
gdp_and_internet_use.dropna(axis=0, how='any')
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4     Afghanistan  2014     1795.735834            6.390000
# 5     Afghanistan  2013     1807.762344            5.900000
# 6     Afghanistan  2012     1772.764974            5.454545
# 7     Afghanistan  2011     1626.764793            5.000000
# 8     Afghanistan  2010     1671.581238            4.000000
# 9     Afghanistan  2009     1502.354073            3.550000
# 10    Afghanistan  2008     1267.644939            1.840000
# 11    Afghanistan  2007     1247.753118            1.900000
# 12    Afghanistan  2006     1123.871323            2.107124
# 13    Afghanistan  2005     1099.104568            1.224148
# 14    Afghanistan  2004     1025.208245            0.105809
# 15    Afghanistan  2003     1055.557459            0.087891
# 16    Afghanistan  2002     1016.245409            0.004561
# 21        Albania  2014    10700.993216           60.100000
# 22        Albania  2013    10492.669028           57.200000
# ...

# %%
years_list = ['2004', '2009', '2014']

# %%
gdp_and_internet_use = gdp_and_internet_use[gdp_and_internet_use.Year.isin(years_list)]

# %%
gdp_and_internet_use = gdp_and_internet_use.dropna(axis=0, how='any')

# %%
gdp_and_internet_use
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4              Afghanistan  2014     1795.735834            6.390000
# 9              Afghanistan  2009     1502.354073            3.550000
# 14             Afghanistan  2004     1025.208245            0.105809
# 21                 Albania  2014    10700.993216           60.100000
# 26                 Albania  2009     9525.377979           41.200000
# 31                 Albania  2004     7001.054082            2.420388
# 50                 Algeria  2014    13557.769757           18.090000
# 55                 Algeria  2009    12697.690780           11.230000
# 60                 Algeria  2004    11845.170512            4.634475
# 79                  Angola  2014     6813.052106           21.260000
# 84                  Angola  2009     6292.534856            6.000000
# 89                  Angola  2004     4604.657044            0.464815
# 108    Antigua and Barbuda  2014    20440.540555           64.000000
# ...

# %% [markdown]
# Create three new data frames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
the_2004 = gdp_and_internet_use[gdp_and_internet_use['Year'] == 2004]

# %%
the_2004
# Out:
#                              Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 14                       Afghanistan  2004     1025.208245            0.105809
# 31                           Albania  2004     7001.054082            2.420388
# 60                           Algeria  2004    11845.170512            4.634475
# 89                            Angola  2004     4604.657044            0.464815
# 118              Antigua and Barbuda  2004    21161.123532           24.266544
# 176                        Argentina  2004    14498.772332           16.036684
# 205                          Armenia  2004     4673.816503            4.899009
# 233                            Aruba  2004    39553.374074           23.000000
# 291                          Austria  2004    40652.811067           54.280000
# 349                          Bahrain  2004    43355.738118           21.458681
# 378                       Bangladesh  2004     1896.763311            0.199036
# ...

# %%
the_2009 = gdp_and_internet[gdp_and_internet['Year'] == 2009].dropna(axis=0, how='any')

# %%
the_2014 = gdp_and_internet[gdp_and_internet['Year'] == 2014].dropna(axis=0, how='any')

# %% [markdown]
# Which country had the highest percentage of internet users in 2014? What was the percentage? Repeat for 2004 and 2009.
# (Try typing the first 3 letters of your DataFrame name and hitting the tab for auto-complete options).
#
#
#         3002	Sweden	 2004		83.89
#         1400	Iceland	 2009		93
#         1395	Iceland	 2014		98.16

# %%
the_2004['Internet_Users_Pct'] = pd.to_numeric(the_2004['Internet_Users_Pct'])
# Out:
# C:\Users\wmcwi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
the_2009['Internet_Users_Pct']= pd.to_numeric(the_2009['Internet_Users_Pct'])

# %%
the_2014['Internet_Users_Pct']= pd.to_numeric(the_2014['Internet_Users_Pct'])

# %%
the_2014['Internet_Users_Pct'].dtype
# Out:
# dtype('float64')

# %%
the_2004['Internet_Users_Pct'].max()
# Out:
# 83.89

# %%
the_2004.loc[the_2004['Internet_Users_Pct'].idxmax()]
# Out:
# Country                Sweden
# Year                     2004
# GDP_Per_Capita        40177.9
# Internet_Users_Pct      83.89
# Name: 5852, dtype: object

# %%
the_2009_max = the_2009['Internet_Users_Pct'].max()
the_2009_max
# Out:
# 93.0

# %%
the_2009.loc[the_2009['Internet_Users_Pct'].idxmax()]
# Out:
# Country               Iceland
# Year                     2009
# GDP_Per_Capita        41505.1
# Internet_Users_Pct         93
# Name: 2586, dtype: object

# %%
the_2014_max = the_2014['Internet_Users_Pct'].max()
the_2014_max
# Out:
# 98.16

# %%
the_2014.loc[the_2014['Internet_Users_Pct'].idxmax()]
# Out:
# Country               Iceland
# Year                     2014
# GDP_Per_Capita        42774.9
# Internet_Users_Pct      98.16
# Name: 2581, dtype: object

# %%
the_2004.sort_values(by='Internet_Users_Pct').tail(3)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1414  Denmark  2004    43670.446201               80.93
# 2591  Iceland  2004    38893.378798               83.88
# 5852   Sweden  2004    40177.850408               83.89

# %% [markdown]
# Which country had the lowest percentage of internet users in 2014? What was the percentage? Repeat for 2004 and 2009.
#
#
#                 2146	Myanmar	     2004	   0.024337
#                 3109    Timor-Leste	 2009	   0.18525151
#                 1275    Timor-Leste	 2014	   1.14

# %%
the_2004_min = the_2004['Internet_Users_Pct'].min()
the_2004_min
# Out:
# 0.024337392000000003

# %%
the_2004.loc[the_2004['Internet_Users_Pct'].idxmin()]
# Out:
# Country                 Myanmar
# Year                       2004
# GDP_Per_Capita          1999.71
# Internet_Users_Pct    0.0243374
# Name: 4238, dtype: object

# %%
the_2009_min = the_2009['Internet_Users_Pct'].min()
the_2009_min
# Out:
# 0.18525151

# %%
the_2009.loc[the_2009['Internet_Users_Pct'].idxmin()]
# Out:
# Country               Timor-Leste
# Year                         2009
# GDP_Per_Capita            9275.53
# Internet_Users_Pct       0.185252
# Name: 6049, dtype: object

# %%
the_2014_min = the_2014['Internet_Users_Pct'].min()
the_2014_min
# Out:
# 1.14

# %%
the_2014.loc[the_2014['Internet_Users_Pct'].idxmin()]
# Out:
# Country               Timor-Leste
# Year                         2014
# GDP_Per_Capita            6466.74
# Internet_Users_Pct           1.14
# Name: 6044, dtype: object

# %%
the_2014.sort_values(by='Internet_Users_Pct').head(3)
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6044  Timor-Leste  2014     6466.737732                1.14
# 794       Burundi  2014      768.469837                1.38
# 2292       Guinea  2014     1836.532318                1.72

# %% [markdown]
# Which country had the highest gdp per capita in 2014? What was the gdp per capita?
#
#                     2556	Qatar	 2014	116693.507701
#
# Which country had the lowest gdp per capita in 2014? What was the gdp per capita?
#
#                     539	    Burundi	 2014	768.469837

# %%
gdp_per_cap_2014_max = the_2014['GDP_Per_Capita'].max()
gdp_per_cap_2014_max
# Out:
# 116693.50770116401

# %%
gdp_per_cap_2014_min = the_2014['GDP_Per_Capita'].min()
gdp_per_cap_2014_min
# Out:
# 768.469836927654

# %%
the_2014.sort_values(by='GDP_Per_Capita').tail(5)
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4530      Norway  2014    63328.259526               96.30
# 3150      Kuwait  2014    72588.670676               78.70
# 5316   Singapore  2014    81965.361071               82.00
# 3610  Luxembourg  2014    92349.186429               94.67
# 5003       Qatar  2014   116693.507701               91.49

# %% [markdown]
# Create some scatterplots:
#
#     a. 2004 Percent Using the Internet vs GDP Per Capita
#
#     b. 2009 Percent Using the Internet vs GDP Per Capita
#
#     c. 2014 Percent Using the Internet vs GDP Per Capita
#
# Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.
#
# convert all data to floats

# %%
plt.scatter(the_2004['Internet_Users_Pct'], the_2004['GDP_Per_Capita'] )

# %%
plt.scatter(the_2009['Internet_Users_Pct'], the_2009['GDP_Per_Capita'] )

# %%
plt.scatter(the_2014['Internet_Users_Pct'], the_2014['GDP_Per_Capita'] )

# %% [markdown]
# Look at the distribution of gdp per capita values for 2014. Is it unimodal?
#
# Look at the distribution of Internet Use for 2014. Is it unimodal?

# %%
the_2014.sort_values(by='GDP_Per_Capita')
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 794                Burundi  2014      768.469837             1.38000
# 4414                 Niger  2014      900.136918             1.95000
# 3697                Malawi  2014     1142.530804             5.83000
# 4199            Mozambique  2014     1222.452874             5.94000
# 3460               Liberia  2014     1257.625441             5.41000
# 1799              Ethiopia  2014     1413.962518             2.90000
# 6063                  Togo  2014     1423.553002             5.70000
# 2321         Guinea-Bissau  2014     1425.770644             3.32000
# 765           Burkina Faso  2014     1582.330098             9.40000
# 3668            Madagascar  2014     1602.933849             3.70000
# 2379                 Haiti  2014     1656.315765            11.40000
# 5079                Rwanda  2014     1667.579916            10.60000
# 5287          Sierra Leone  2014     1707.097335             2.10000
# ...

# %%
plt.hist(the_2014['GDP_Per_Capita'])
# Out:
# (array([83., 33., 21., 16.,  4.,  3.,  1.,  2.,  0.,  1.]),
#  array([   768.46983693,  12360.97362335,  23953.47740977,  35545.9811962 ,
#          47138.48498262,  58730.98876905,  70323.49255547,  81915.99634189,
#          93508.50012832, 105101.00391474, 116693.50770116]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(the_2014['Internet_Users_Pct'])
# Out:
# (array([28., 26.,  8.,  8., 23., 12., 16., 15., 16., 12.]),
#  array([ 1.14 , 10.842, 20.544, 30.246, 39.948, 49.65 , 59.352, 69.054,
#         78.756, 88.458, 98.16 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# What are the top 5 countries in terms of internet use in 2014?

# %%
the_2014.sort_values('Internet_Users_Pct').tail()
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4327  Netherlands  2014    46238.209707               93.17
# 3610   Luxembourg  2014    92349.186429               94.67
# 1404      Denmark  2014    45057.083449               95.99
# 4530       Norway  2014    63328.259526               96.30
# 2581      Iceland  2014    42774.888849               98.16

# %% [markdown]
# Create a data frame called top_5_internet from the combined data frame that has all three years for these 5 countries.
# You should have 15 rows. Check that this is true.

# %%
top_5_list= ['Netherlands', 'Luxembourg', 'Denmark', 'Norway', 'Iceland']
top_5_internet = gdp_and_internet_use[gdp_and_internet_use['Country'].isin(top_5_list) &
                                       gdp_and_internet_use['Year'].isin(years_list)]

# %%
top_5_internet = top_5_internet.sort_values('Year')
top_5_internet
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1414      Denmark  2004    43670.446201               80.93
# 2591      Iceland  2004    38893.378798               83.88
# 3620   Luxembourg  2004    87209.819367               65.88
# 4337  Netherlands  2004    43048.313770               68.52
# 4540       Norway  2004    61612.275634               77.69
# 1409      Denmark  2009    43382.615688               86.84
# 2586      Iceland  2009    41505.084834               93.00
# 3615   Luxembourg  2009    89098.734264               87.31
# 4332  Netherlands  2009    45724.862764               89.63
# 4535       Norway  2009    62617.153609               92.08
# 1404      Denmark  2014    45057.083449               95.99
# 2581      Iceland  2014    42774.888849               98.16
# 3610   Luxembourg  2014    92349.186429               94.67
# 4327  Netherlands  2014    46238.209707               93.17
# 4530       Norway  2014    63328.259526               96.30

# %% [markdown]
# Create a seaborn FacetGrid to show the internet usage trend over time for these 5 countries
# (those with the highest reported internet use in 2014).
# Which country had the greatest growth between 2004 and 2014? Is there a plotting issue with Bermuda? Can you fix it?

# %%
g = sns.FacetGrid(top_5_internet, col = 'Year', hue='Country', col_wrap=2, height=8)

g.map(plt.bar, 'Country', 'Internet_Users_Pct')

# %%
grid = sns.FacetGrid(top_5_internet, 
                     col="Year", hue="Country", col_wrap=2, height=8)

grid.map(plt.bar, "Country", "Internet_Users_Pct")
grid.add_legend(ncol = 2, title = 'Highest % Internet Users')

# %% [markdown]
# Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage.
# Which country has consistently had the least internet use?

# %%
the_2014.sort_values('Internet_Users_Pct').head()
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6044   Timor-Leste  2014     6466.737732                1.14
# 794        Burundi  2014      768.469837                1.38
# 2292        Guinea  2014     1836.532318                1.72
# 4414         Niger  2014      900.136918                1.95
# 5287  Sierra Leone  2014     1707.097335                2.10

# %%
bottom_country_list = ['Timor-Leste', 'Burundi', 'Guinea', 'Niger', 'Sierra Leone']
bottom_5_internet = gdp_and_internet_use[gdp_and_internet_use['Year'].isin(years_list) &
                                        gdp_and_internet_use['Country'].isin(bottom_country_list)]

# %%
bottom_5_internet
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 794        Burundi  2014      768.469837            1.380000
# 799        Burundi  2009      721.063140            0.900000
# 804        Burundi  2004      708.833720            0.349060
# 2292        Guinea  2014     1836.532318            1.720000
# 2297        Guinea  2009     1626.288463            0.940000
# 2302        Guinea  2004     1583.864869            0.508819
# 4414         Niger  2014      900.136918            1.950000
# 4419         Niger  2009      778.982257            0.760000
# 4424         Niger  2004      757.751262            0.189934
# 5287  Sierra Leone  2014     1707.097335            2.100000
# 5292  Sierra Leone  2009     1172.862734            0.260000
# 5297  Sierra Leone  2004     1057.693494            0.203008
# 6044   Timor-Leste  2014     6466.737732            1.140000
# 6049   Timor-Leste  2009     9275.529371            0.185252

# %%
g_1 = sns.FacetGrid(bottom_5_internet, col = 'Year', hue='Country', col_wrap=2, height=8)

g_1.map(plt.bar, 'Country', 'Internet_Users_Pct')

# %% [markdown]
# Repeat this one more time to look at 10-year trend for the bottom 5 countries for 2014 in terms of GDP per capita.

# %%
bottom_5_internet_1 = gdp_and_internet_use[gdp_and_internet_use['Year'].isin([2004, 2014]) &
                                        gdp_and_internet_use['Country'].isin(bottom_country_list)]

# %%
g_2 = sns.FacetGrid(bottom_5_internet_1, col = 'Year', hue='Country', col_wrap=2, height=8)

g_2.map(plt.bar, 'Country', 'Internet_Users_Pct')

# %% [markdown]
# Is there anything surprising or unusual in any of these plots? Searching on the internet,
# can you find any possible explanations for unusual findings?
